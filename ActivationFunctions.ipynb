# %% [markdown]
# #Experiment 4: Varying Activation function

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

#Load and preprocess CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

#Image Normalization
train_images, test_images = train_images / 255.0, test_images / 255.0

# Example CNN model with varying activation functions
activation_functions = ['relu', 'tanh', 'sigmoid', 'swish']

for activation_function in activation_functions:
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), activation=activation_function, input_shape=(32, 32, 3)),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation=activation_function),
        layers.Dense(10)
    ])

    # Compile and train the model for each activation function
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

    # Plot accuracy and loss curves for this activation function
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'Activation Function: {activation_function}')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.title(f'Activation Function: {activation_function}')

    plt.show()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 80s 48ms/step - loss: 1.4507 - accuracy: 0.4798 - val_loss: 1.2413 - val_accuracy: 0.5616
# Epoch 2/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 1.1449 - accuracy: 0.5965 - val_loss: 1.1531 - val_accuracy: 0.5932
# Epoch 3/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 1.0113 - accuracy: 0.6479 - val_loss: 1.0677 - val_accuracy: 0.6264
# Epoch 4/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.9147 - accuracy: 0.6796 - val_loss: 1.0409 - val_accuracy: 0.6364
# Epoch 5/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.8377 - accuracy: 0.7066 - val_loss: 1.0025 - val_accuracy: 0.6539
# Epoch 6/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.7629 - accuracy: 0.7340 - val_loss: 1.0542 - val_accuracy: 0.6464
# Epoch 7/10
# ...
